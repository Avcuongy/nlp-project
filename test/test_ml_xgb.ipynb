# %% [markdown]
# ---
#
# # Lib

# %%
import joblib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)

from xgboost import XGBClassifier
import optuna

# %% [markdown]
# ---
#
# # Read file

# %%
df_train = pd.read_csv("../data/processed/train.csv", encoding="utf-8")
df_val = pd.read_csv("../data/processed/val.csv", encoding="utf-8")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3592 entries, 0 to 3591
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   comment  3592 non-null   object
#  1   label    3592 non-null   object
# dtypes: object(2)
# memory usage: 56.2+ KB

# %%
df_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1540 entries, 0 to 769
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   comment  1540 non-null   object
#  1   label    1540 non-null   object
# dtypes: object(2)
# memory usage: 36.1+ KB

# %% [markdown]
# ---
#
# # Labels

# %% [markdown]
# ## Train

# %%
matrix_labels_train = df_train["label"]

# %%
matrix_labels_train.head()
# Out:
# 0    negative
# 1    positive
# 2     neutral
# 3    positive
# 4    negative
# Name: label, dtype: object

# %%
print(f"Number of labels: {len(matrix_labels_train.unique())}")
print(f"Labels: {matrix_labels_train.unique()}")
# Out:
# Number of labels: 3
# Labels: ['negative' 'positive' 'neutral']

# %% [markdown]
# ## Val

# %%
matrix_labels_val = df_val["label"]

# %%
matrix_labels_val.head()
# Out:
# 0    positive
# 1    positive
# 2    positive
# 3    negative
# 4    positive
# Name: label, dtype: object

# %%
print(f"Number of labels: {len(matrix_labels_val.unique())}")
print(f"Labels: {matrix_labels_val.unique()}")
# Out:
# Number of labels: 3
# Labels: ['positive' 'negative' 'neutral']

# %% [markdown]
# ---
#
# # Train, val split

# %%
# Train
X_train = df_train[["comment"]]
y_train = matrix_labels_train

# Validation
X_val = df_val[["comment"]]
y_val = matrix_labels_val

# %%
# Encode labels
le = LabelEncoder()
y_train = le.fit_transform(y_train).astype(np.int64)
print(f"Labels: {le.classes_}")
# Out:
# Labels: ['negative' 'neutral' 'positive']

# %% [markdown]
# ---
#
# # Vectorize

# %%
vec = TfidfVectorizer(
    analyzer="char",
    min_df=2,
    max_df=0.95,
    ngram_range=(3, 5),
    max_features=30000,
)

# %%
# Fit TF-IDF on training and transform train/test
X_train_vec = vec.fit_transform(X_train["comment"])
X_val_vec = vec.transform(X_val["comment"])

# %%
print(f"Train shape: {X_train_vec.shape}")
print(f"Test shape: {X_val_vec.shape}")
print(f"Vocabulary size: {len(vec.get_feature_names_out())}")
# Out:
# Train shape: (3592, 30000)
# Test shape: (1540, 30000)
# Vocabulary size: 30000

# %% [markdown]
# ---
#
# # Load Model

# %%
# Define a StratifiedKFold splitters
cv_splitter = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# ---
#
# ## Xgboost

# %% [markdown]
# ### Model

# %%
def objective(trial):

    params = {
        "objective": "multi:softprob",
        "num_class": 3,
        "eval_metric": "mlogloss",
        "tree_method": "hist",
        "random_state": 42,
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 1.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 1.0),
    }

    skf = cv_splitter
    f1_scores = []

    for train_idx, val_idx in skf.split(X_train_vec, y_train):
        X_tr, X_val = X_train_vec[train_idx], X_train_vec[val_idx]
        y_tr, y_val = y_train[train_idx], y_train[val_idx]

        model = XGBClassifier(**params)
        model.fit(X_tr, y_tr)

        y_pred = model.predict(X_val)
        f1 = f1_score(y_val, y_pred, average="macro")
        f1_scores.append(f1)

    return np.mean(f1_scores)

# %%
study = optuna.create_study(direction="maximize", study_name="xgb_f1_macro")
study.optimize(objective, n_trials=20)
# Out:
# [I 2025-12-20 13:28:56,292] A new study created in memory with name: xgb_f1_macro
# [I 2025-12-20 13:30:39,572] Trial 0 finished with value: 0.44711505342331714 and parameters: {'max_depth': 3, 'learning_rate': 0.04063674798433194, 'n_estimators': 309, 'subsample': 0.641823779381439, 'colsample_bytree': 0.8200463980140058, 'gamma': 2.807290046137219, 'reg_alpha': 0.36802018685071575, 'reg_lambda': 0.866724987602659}. Best is trial 0 with value: 0.44711505342331714.
# [I 2025-12-20 13:35:00,986] Trial 1 finished with value: 0.45830390536127635 and parameters: {'max_depth': 6, 'learning_rate': 0.032537891247789504, 'n_estimators': 451, 'subsample': 0.995022077357469, 'colsample_bytree': 0.8615937110424611, 'gamma': 1.303114459170851, 'reg_alpha': 0.3671342562260991, 'reg_lambda': 0.6035285406375067}. Best is trial 1 with value: 0.45830390536127635.
# [I 2025-12-20 13:38:12,045] Trial 2 finished with value: 0.4857946661590106 and parameters: {'max_depth': 6, 'learning_rate': 0.10753354179711426, 'n_estimators': 350, 'subsample': 0.5943251295073599, 'colsample_bytree': 0.9429023178799916, 'gamma': 0.8624891672133134, 'reg_alpha': 0.2920356177513658, 'reg_lambda': 0.9164506917703773}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 13:40:50,064] Trial 3 finished with value: 0.46035197041155584 and parameters: {'max_depth': 8, 'learning_rate': 0.12339596911228248, 'n_estimators': 611, 'subsample': 0.5208255002033554, 'colsample_bytree': 0.9246110797905784, 'gamma': 3.4139908242193644, 'reg_alpha': 0.8706452492459291, 'reg_lambda': 0.9107562863290268}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 13:43:21,404] Trial 4 finished with value: 0.4768441710568432 and parameters: {'max_depth': 3, 'learning_rate': 0.16220291387977873, 'n_estimators': 584, 'subsample': 0.8091146254249859, 'colsample_bytree': 0.5579752931920302, 'gamma': 1.1690242813743978, 'reg_alpha': 0.5694812507799132, 'reg_lambda': 0.6666251900372632}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 13:45:35,655] Trial 5 finished with value: 0.43692300066685874 and parameters: {'max_depth': 7, 'learning_rate': 0.03324336482258491, 'n_estimators': 455, 'subsample': 0.7897113373726831, 'colsample_bytree': 0.6285367354817699, 'gamma': 4.671838987675909, 'reg_alpha': 0.3094901528808238, 'reg_lambda': 0.9678072763411794}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 13:48:10,831] Trial 6 finished with value: 0.47769583533088555 and parameters: {'max_depth': 4, 'learning_rate': 0.24335443802726225, 'n_estimators': 696, 'subsample': 0.5585641593124918, 'colsample_bytree': 0.6511694143662308, 'gamma': 2.71518164269845, 'reg_alpha': 0.6308496482865013, 'reg_lambda': 0.33912151871338136}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 13:51:33,079] Trial 7 finished with value: 0.47384884562725915 and parameters: {'max_depth': 4, 'learning_rate': 0.12606653840748633, 'n_estimators': 639, 'subsample': 0.5708695031439771, 'colsample_bytree': 0.8947695826266717, 'gamma': 1.3695088047917787, 'reg_alpha': 0.9539796642983246, 'reg_lambda': 0.47158939923964227}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 13:55:41,526] Trial 8 finished with value: 0.4739413207342487 and parameters: {'max_depth': 4, 'learning_rate': 0.1282223856826895, 'n_estimators': 754, 'subsample': 0.86055900949766, 'colsample_bytree': 0.7831559059941186, 'gamma': 0.9309164953628302, 'reg_alpha': 0.12659258489992584, 'reg_lambda': 0.9802491232957938}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 13:59:24,074] Trial 9 finished with value: 0.45110287006217453 and parameters: {'max_depth': 4, 'learning_rate': 0.024475577186076864, 'n_estimators': 777, 'subsample': 0.7161733987118593, 'colsample_bytree': 0.630343265468669, 'gamma': 4.276393718178353, 'reg_alpha': 0.19240460022046074, 'reg_lambda': 0.2096472265011444}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 14:03:40,298] Trial 10 finished with value: 0.4749605752957378 and parameters: {'max_depth': 10, 'learning_rate': 0.06741906981569429, 'n_estimators': 210, 'subsample': 0.6687605113437325, 'colsample_bytree': 0.9987522896641755, 'gamma': 0.1260921928227704, 'reg_alpha': 0.010399744041021564, 'reg_lambda': 0.7114526577054809}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 14:05:11,689] Trial 11 finished with value: 0.47324106634079444 and parameters: {'max_depth': 6, 'learning_rate': 0.2838592089852019, 'n_estimators': 347, 'subsample': 0.5791427998943393, 'colsample_bytree': 0.7086813977327248, 'gamma': 2.3816255895399343, 'reg_alpha': 0.652324001652001, 'reg_lambda': 0.3113479001980992}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 14:07:51,922] Trial 12 finished with value: 0.42679862122319834 and parameters: {'max_depth': 5, 'learning_rate': 0.010799850023268831, 'n_estimators': 351, 'subsample': 0.5179018930920657, 'colsample_bytree': 0.7229501401716124, 'gamma': 2.2489280041012965, 'reg_alpha': 0.7217668231320867, 'reg_lambda': 0.06497363702631542}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 14:09:49,084] Trial 13 finished with value: 0.46310878265913435 and parameters: {'max_depth': 8, 'learning_rate': 0.21114300375263928, 'n_estimators': 528, 'subsample': 0.6160228911429035, 'colsample_bytree': 0.504210055334395, 'gamma': 3.2998491272087587, 'reg_alpha': 0.46369763264033137, 'reg_lambda': 0.3690887845321115}. Best is trial 2 with value: 0.4857946661590106.
# [I 2025-12-20 14:16:27,767] Trial 14 finished with value: 0.48725435270910095 and parameters: {'max_depth': 5, 'learning_rate': 0.07590214057473325, 'n_estimators': 697, 'subsample': 0.7058329982069236, 'colsample_bytree': 0.9920929369117178, 'gamma': 0.0675097620876346, 'reg_alpha': 0.7681049077910618, 'reg_lambda': 0.02181451468909168}. Best is trial 14 with value: 0.48725435270910095.
# [I 2025-12-20 14:20:21,804] Trial 15 finished with value: 0.4792658762785965 and parameters: {'max_depth': 7, 'learning_rate': 0.07225063791999843, 'n_estimators': 259, 'subsample': 0.7110393945889393, 'colsample_bytree': 0.9946428193261123, 'gamma': 0.04154140976720555, 'reg_alpha': 0.7491136731077044, 'reg_lambda': 0.059349910469733425}. Best is trial 14 with value: 0.48725435270910095.
# [I 2025-12-20 14:24:11,412] Trial 16 finished with value: 0.4755598019736782 and parameters: {'max_depth': 5, 'learning_rate': 0.08527329090699035, 'n_estimators': 441, 'subsample': 0.8842107263832395, 'colsample_bytree': 0.9378173800574585, 'gamma': 0.633537232792156, 'reg_alpha': 0.48452435240294855, 'reg_lambda': 0.7989860471514836}. Best is trial 14 with value: 0.48725435270910095.
# [I 2025-12-20 14:28:31,673] Trial 17 finished with value: 0.46740220526350695 and parameters: {'max_depth': 9, 'learning_rate': 0.04842134506416348, 'n_estimators': 531, 'subsample': 0.6735753059551439, 'colsample_bytree': 0.954052565872559, 'gamma': 1.797741683489963, 'reg_alpha': 0.8053673364797527, 'reg_lambda': 0.5241508212434091}. Best is trial 14 with value: 0.48725435270910095.
# [I 2025-12-20 14:32:29,142] Trial 18 finished with value: 0.4423361238033211 and parameters: {'max_depth': 5, 'learning_rate': 0.017463318636723343, 'n_estimators': 388, 'subsample': 0.7737644313861869, 'colsample_bytree': 0.8497637832670102, 'gamma': 0.5724490073576529, 'reg_alpha': 0.978115195150065, 'reg_lambda': 0.20128843168083263}. Best is trial 14 with value: 0.48725435270910095.
# [I 2025-12-20 14:36:12,128] Trial 19 finished with value: 0.4650395929953447 and parameters: {'max_depth': 6, 'learning_rate': 0.08853336282277206, 'n_estimators': 691, 'subsample': 0.7270422048795714, 'colsample_bytree': 0.7904701937334839, 'gamma': 1.9174594456911982, 'reg_alpha': 0.2643127097302919, 'reg_lambda': 0.7381317752823955}. Best is trial 14 with value: 0.48725435270910095.

# %%
print("Best f1-macro:", study.best_value)
print("Best trial:", study.best_trial.number)
# Out:
# Best f1-macro: 0.48725435270910095
# Best trial: 14

# %%
best_params = study.best_params

print("Best params:")
for k, v in best_params.items():
    print(f"  {k}: {v}")
# Out:
# Best params:
#   max_depth: 5
#   learning_rate: 0.07590214057473325
#   n_estimators: 697
#   subsample: 0.7058329982069236
#   colsample_bytree: 0.9920929369117178
#   gamma: 0.0675097620876346
#   reg_alpha: 0.7681049077910618
#   reg_lambda: 0.02181451468909168

# %%
# Build final model with best hyperparameters
best_params.update(
    {
        "objective": "multi:softprob",
        "num_class": 3,
        "eval_metric": "mlogloss",
        "tree_method": "hist",
        "random_state": 42,
    }
)

xgb_model = XGBClassifier(**best_params)

# %%
xgb_model.fit(X_train_vec, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9920929369117178, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='mlogloss', feature_types=None, feature_weights=None,
#               gamma=0.0675097620876346, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.07590214057473325,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=697, n_jobs=None, num_class=3, ...)

# %% [markdown]
# ### Eval validation

# %%
y_pred = xgb_model.predict(X_val_vec)
y_pred = le.inverse_transform(y_pred)

# %%
print(f"accuracy: {accuracy_score(y_val, y_pred):.4f}")
print(
    f"precision: {precision_score(y_val, y_pred, average='macro', zero_division=0):.4f}"
)
print(f"recall: {recall_score(y_val, y_pred, average='macro', zero_division=0):.4f}")
print(f"f1: {f1_score(y_val, y_pred, average='macro', zero_division=0):.4f}")
# Out:
# accuracy: 0.6623
# precision: 0.5345
# recall: 0.5027
# f1: 0.4972

# %%
# Classified report
print(classification_report(y_val, y_pred, target_names=le.classes_, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.66      0.66      0.66       607
#      neutral       0.26      0.06      0.10       156
#     positive       0.68      0.79      0.73       777
#
#     accuracy                           0.66      1540
#    macro avg       0.53      0.50      0.50      1540
# weighted avg       0.63      0.66      0.64      1540

# %% [markdown]
# ### Test

# %%
df_test = pd.read_csv("../data/processed/test.csv")
df_test_predict = df_test.copy()
df_test_predict.head()
# Out:
#         brand    model version  year segment  \
# 0  mitsubishi  attrage     cvt  2025   sedan
# 1      nissan   almera     NaN  2025   sedan
# 2          mg        5  luxury  2025   sedan
# 3     hyundai    creta  n line  2025     suv
# 4      toyota     vios     NaN  2025   sedan
#
#                                              comment     label
# 0                            ngoại thất hiện_đại hẳn  positive
# 1  thương_hiệu ninsan chỗ chê gtr nổi_tiếng khấp ...  positive
# 2                         xe trung_quốc thiết_kế đẹp  positive
# 3                                      giá trưng_bày  negative
# 4  vụ tai_nạn mấy hôm trung_quốc vios sởn gai_ốc ...  negative

# %%
# Try prediction on some samples
samples = df_test["comment"].tolist()
samples_vec = vec.transform(samples).toarray()

# Use the trained final model for predictions
probs = xgb_model.predict(samples_vec) 
preds = np.argmax(probs, axis=1)

for i, (text, pred_idx) in enumerate(zip(samples, preds)):
    label_name = le.inverse_transform([pred_idx])[0]
    confidence = probs[i][pred_idx]
    df_test_predict.at[i, "predicted_label"] = label_name
    df_test_predict.at[i, "confidence"] = confidence

# %%
print(classification_report(df_test["label"], df_test_predict["predicted_label"], target_names=le.classes_, zero_division=0))

# %%
# Confusion matrix
cm = confusion_matrix(df_test_predict["label"], df_test_predict["predicted_label"])

# Plot confusion matrix
plt.figure(figsize=(8, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="coolwarm",
    xticklabels=le.classes_,
    yticklabels=le.classes_,
    cbar_kws={"label": "Count"},
)
plt.title("Confusion matrix", pad=20)
plt.ylabel("True", fontsize=12)
plt.xlabel("Predicted", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # Save model

# %%
model_save_path = "../models/ml/"

# Save XGBoost model
joblib.dump(xgb_model, model_save_path + "xgboost.pkl")
print(f"XGBoost model saved to {model_save_path}xgboost.pkl")
